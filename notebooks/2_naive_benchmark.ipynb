# %% [markdown]
# This notebook produces the forecasts with the naive method of just copying the last known value (equivalent to AR(1) without the noise component). This will be used as a benchmark for my models

# %%
import numpy as np
import pandas as pd
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))
from models_code.naive_forecast import naive_forecast

# %%
cpi = pd.read_csv('..\\data\\structured_data\\CPI_growth_yoy_dataframe.csv')
rgdp = pd.read_csv('..\\data\\structured_data\\RGDP_growth_dataframe.csv')
unemp = pd.read_csv('..\\data\\structured_data\\unemployment_rate_dataframe.csv')
# dropping the unwanted duplicate columns and indexes, renaming the observed value columns
cpi = cpi.drop(['Unnamed: 0'], axis = 1).rename(columns = {'OBS_VALUE': 'CPI inflation'})
rgdp = rgdp.drop(['Unnamed: 0', 'Reference area', 'TIME_PERIOD'], axis = 1).rename(columns = {'OBS_VALUE': 'RGDP growth'})
unemp = unemp.drop(['Unnamed: 0', 'Reference area', 'TIME_PERIOD'], axis = 1).rename(columns = {'OBS_VALUE': 'Unemp rate'})
# concatenating along the columns
df = pd.concat((cpi, rgdp, unemp), axis = 1)

# %%
result_df = naive_forecast(df, test_years = [2015, 2019])
result_df
# Out:
#     Reference area TIME_PERIOD  CPI inflation  RGDP growth  Unemp rate  \
# 0        Australia     2015-Q1       1.328274     0.969735    6.202810
# 1        Australia     2015-Q2       1.510856     0.118178    6.016903
# 2        Australia     2015-Q3       1.503726     0.974271    6.178764
# 3        Australia     2015-Q4       1.688528     0.620688    5.834710
# 4        Australia     2016-Q1       1.310883     0.916476    5.796363
# ..             ...         ...            ...          ...         ...
# 435  United States     2018-Q4       2.203150     0.141644    3.833333
# 436  United States     2019-Q1       1.644898     0.624318    3.866667
# 437  United States     2019-Q2       1.811376     0.835146    3.633333
# 438  United States     2019-Q3       1.757537     1.170002    3.600000
# 439  United States     2019-Q4       2.032942     0.681878    3.600000
#
#      Forecasts
# 0     6.253474
# 1     6.202810
# 2     6.016903
# 3     6.178764
# 4     5.834710
# ..         ...
# 435   3.766667
# 436   3.833333
# 437   3.866667
# 438   3.633333
# 439   3.600000
#
# [440 rows x 6 columns]

# %%
result_df.to_csv('..\\data\\forecasts\\naive_forecast_dataframe.csv')
